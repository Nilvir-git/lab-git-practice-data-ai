# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Nil"
reason = "I'm interested in learning Data & Analytics so the knowledge can boost my chances in job searching "
fun_fact = "My objective for this course is to upgrate my skills and develop passion for the data world"

print(f"Hi! My name is {name}. {reason}. {fun_fact}.")
# Out:
# Hi! My name is Nil. I'm interested in learning Data & Analytics so the knowledge can boost my chances in job searching . My objective for this course is to upgrate my skills and develop passion for the data world.
